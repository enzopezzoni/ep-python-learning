# %%
import requests

url = "https://free-nba.p.rapidapi.com/players"

querystring = {"page":"0","per_page":"25"}

headers = {
	"X-RapidAPI-Key": "b219701248mshb04aa2cc33acbcfp125dcajsn5722c9a34659",
	"X-RapidAPI-Host": "free-nba.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': [{'id': 14, 'first_name': 'Ike', 'height_feet': None, 'height_inches': None, 'last_name': 'Anigbogu', 'position': 'C', 'team': {'id': 12, 'abbreviation': 'IND', 'city': 'Indiana', 'conference': 'East', 'division': 'Central', 'full_name': 'Indiana Pacers', 'name': 'Pacers'}, 'weight_pounds': None}, {'id': 25, 'first_name': 'Ron', 'height_feet': None, 'height_inches': None, 'last_name': 'Baker', 'position': 'G', 'team': {'id': 20, 'abbreviation': 'NYK', 'city': 'New York', 'conference': 'East', 'division': 'Atlantic', 'full_name': 'New York Knicks', 'name': 'Knicks'}, 'weight_pounds': None}, {'id': 47, 'first_name': 'Jabari', 'height_feet': None, 'height_inches': None, 'last_name': 'Bird', 'position': 'G', 'team': {'id': 2, 'abbreviation': 'BOS', 'city': 'Boston', 'conference': 'East', 'division': 'Atlantic', 'full_name': 'Boston Celtics', 'name': 'Celtics'}, 'weight_pounds': None}, {'id': 67, 'first_name': 'MarShon', 'height_feet': None, 'height_inches': None, 'last_name': 'B
# ...

# %%
#how do we convert json into a pandas dataframe
import pandas as pd
from pandas import json_normalize


nba_players = response.json()['data']
players_dataframe = json_normalize(nba_players)

players_dataframe
# Out:
#       id first_name  ...          team.full_name      team.name
# 0     14        Ike  ...          Indiana Pacers         Pacers
# 1     25        Ron  ...         New York Knicks         Knicks
# 2     47     Jabari  ...          Boston Celtics        Celtics
# 3     67    MarShon  ...       Memphis Grizzlies      Grizzlies
# 4     71    Lorenzo  ...         Toronto Raptors        Raptors
# 5     90       Omri  ...       Memphis Grizzlies      Grizzlies
# 6      1       Alex  ...   Oklahoma City Thunder        Thunder
# 7    119      Tyler  ...   Oklahoma City Thunder        Thunder
# 8    149     Keenan  ...         Detroit Pistons        Pistons
# 9    179     Marcin  ...             LA Clippers       Clippers
# 10  1593     Andrew  ...   Golden State Warriors       Warriors
# 11   241       Amir  ...      Philadelphia 76ers          76ers
# 12   392    Malachi  ...               Utah Jazz           Jazz
# 13   281       Zach  ...         Detroit Pistons        Pistons
# ...
